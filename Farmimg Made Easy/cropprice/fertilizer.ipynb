# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\lahar\AppData\Local\Temp\ipykernel_18812\265554930.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
crop_data=pd.read_csv("Fertilizer Prediction.csv")
crop_data
# Out:
#                                           Temparature  Humidity   Moisture  \
# 0                                                  26       52.0      38.0
# 1                                                  29       52.0      45.0
# 2                                                  34       65.0      62.0
# 3                                                  32       62.0      34.0
# 4                                                  28       54.0      46.0
# ..                                                ...        ...       ...
# 95                                                 30       60.0      27.0
# 96                                                 38       72.0      51.0
# 97                                                 36       60.0      43.0
# 98                                                 29       58.0      57.0
# 99  C:\Users\lahar\Downloads\cropprice (1)\croppri...        NaN       NaN
#
#    Soil Type  Crop Type  Nitrogen  Potassium  Phosphorous Fertilizer Name
# 0      Sandy      Maize      37.0        0.0          0.0            Urea
# 1      Loamy  Sugarcane      12.0        0.0         36.0             DAP
# 2      Black     Cotton       7.0        9.0         30.0        14-35-14
# 3        Red    Tobacco      22.0        0.0         20.0           28-28
# 4     Clayey      Paddy      35.0        0.0          0.0            Urea
# ..       ...        ...       ...        ...          ...             ...
# 95       Red    Tobacco       4.0       17.0         17.0        10-26-26
# 96     Loamy      Wheat      39.0        0.0          0.0            Urea
# 97     Sandy    Millets      15.0        0.0         41.0             DAP
# 98     Black  Sugarcane      12.0        0.0         10.0           20-20
# 99       NaN        NaN       NaN        NaN          NaN             NaN
#
# [100 rows x 9 columns]

# %%
crop_data.shape
# Out:
# (100, 9)

# %%
crop_data.columns
# Out:
# Index(['Temparature', 'Humidity ', 'Moisture', 'Soil Type', 'Crop Type',
#        'Nitrogen', 'Potassium', 'Phosphorous', 'Fertilizer Name'],
#       dtype='object')

# %%
crop_data.describe()
# Out:
#        Humidity    Moisture   Nitrogen  Potassium  Phosphorous
# count  99.000000  99.000000  99.000000  99.000000    99.000000
# mean   59.151515  43.181818  18.909091   3.383838    18.606061
# std     5.840331  11.271568  11.599693   5.814667    13.476978
# min    50.000000  25.000000   4.000000   0.000000     0.000000
# 25%    54.000000  34.000000  10.000000   0.000000     9.000000
# 50%    60.000000  41.000000  13.000000   0.000000    19.000000
# 75%    64.000000  50.500000  24.000000   7.500000    30.000000
# max    72.000000  65.000000  42.000000  19.000000    42.000000

# %%
crop_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Temparature      100 non-null    object
#  1   Humidity         99 non-null     float64
#  2   Moisture         99 non-null     float64
#  3   Soil Type        99 non-null     object
#  4   Crop Type        99 non-null     object
#  5   Nitrogen         99 non-null     float64
#  6   Potassium        99 non-null     float64
#  7   Phosphorous      99 non-null     float64
#  8   Fertilizer Name  99 non-null     object
# dtypes: float64(5), object(4)
# memory usage: 7.2+ KB

# %%
crop_data.isnull().sum()
# Out:
# Temparature        0
# Humidity           1
# Moisture           1
# Soil Type          1
# Crop Type          1
# Nitrogen           1
# Potassium          1
# Phosphorous        1
# Fertilizer Name    1
# dtype: int64

# %%
crop_data = crop_data.dropna()
crop_data
# Out:
#    Temparature  Humidity   Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0           26       52.0      38.0     Sandy      Maize      37.0        0.0
# 1           29       52.0      45.0     Loamy  Sugarcane      12.0        0.0
# 2           34       65.0      62.0     Black     Cotton       7.0        9.0
# 3           32       62.0      34.0       Red    Tobacco      22.0        0.0
# 4           28       54.0      46.0    Clayey      Paddy      35.0        0.0
# ..         ...        ...       ...       ...        ...       ...        ...
# 94          25       50.0      32.0    Clayey     Pulses      24.0        0.0
# 95          30       60.0      27.0       Red    Tobacco       4.0       17.0
# 96          38       72.0      51.0     Loamy      Wheat      39.0        0.0
# 97          36       60.0      43.0     Sandy    Millets      15.0        0.0
# 98          29       58.0      57.0     Black  Sugarcane      12.0        0.0
#
#     Phosphorous Fertilizer Name
# 0           0.0            Urea
# 1          36.0             DAP
# 2          30.0        14-35-14
# 3          20.0           28-28
# 4           0.0            Urea
# ..          ...             ...
# 94         19.0           28-28
# 95         17.0        10-26-26
# 96          0.0            Urea
# 97         41.0             DAP
# 98         10.0           20-20
#
# [99 rows x 9 columns]

# %%
crop_data.isnull().values.any()
# Out:
# False

# %%
# %pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\python311\lib\site-packages (3.8.2)
# Requirement already satisfied: seaborn in c:\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python311\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python311\lib\site-packages (from matplotlib) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\python311\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lahar\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\python311\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python311\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lahar\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in c:\python311\lib\site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\lahar\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming crop_data is a pandas DataFrame containing State_Name and Production columns

sns.barplot(x=crop_data["Fertilizer Name"], y=crop_data["Soil Type"])
plt.xticks(rotation=0)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming crop_data is a pandas DataFrame containing Crop_Year and Production columns

sns.barplot(x=crop_data["Crop Type"], y=crop_data["Fertilizer Name"])
plt.yticks(rotation=90)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming crop_data is a pandas DataFrame containing Season and Yield columns

sns.lineplot(x=crop_data["Nitrogen"], y=crop_data["Crop Type"])
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming crop_data is a pandas DataFrame containing Season and Yield columns

sns.lineplot(x=crop_data["Potassium"], y=crop_data["Crop Type"])
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming crop_data is a pandas DataFrame containing Season and Yield columns

sns.lineplot(x=crop_data["Phosphorous"], y=crop_data["Crop Type"])
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming crop_data is a pandas DataFrame containing Season and Yield columns

sns.lineplot(x=crop_data["Nitrogen"], y=crop_data["Soil Type"])
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming crop_data is a pandas DataFrame containing Season and Yield columns

sns.lineplot(x=crop_data["Potassium"], y=crop_data["Soil Type"])
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming crop_data is a pandas DataFrame containing Season and Yield columns

sns.lineplot(x=crop_data["Phosphorous"], y=crop_data["Soil Type"])
plt.xticks(rotation=90)
plt.show()

# %%
crop_data = pd.read_csv("Fertilizer Prediction.csv")
crop_data
# Out:
#                                           Temparature  Humidity   Moisture  \
# 0                                                  26       52.0      38.0
# 1                                                  29       52.0      45.0
# 2                                                  34       65.0      62.0
# 3                                                  32       62.0      34.0
# 4                                                  28       54.0      46.0
# ..                                                ...        ...       ...
# 95                                                 30       60.0      27.0
# 96                                                 38       72.0      51.0
# 97                                                 36       60.0      43.0
# 98                                                 29       58.0      57.0
# 99  C:\Users\lahar\Downloads\cropprice (1)\croppri...        NaN       NaN
#
#    Soil Type  Crop Type  Nitrogen  Potassium  Phosphorous Fertilizer Name
# 0      Sandy      Maize      37.0        0.0          0.0            Urea
# 1      Loamy  Sugarcane      12.0        0.0         36.0             DAP
# 2      Black     Cotton       7.0        9.0         30.0        14-35-14
# 3        Red    Tobacco      22.0        0.0         20.0           28-28
# 4     Clayey      Paddy      35.0        0.0          0.0            Urea
# ..       ...        ...       ...        ...          ...             ...
# 95       Red    Tobacco       4.0       17.0         17.0        10-26-26
# 96     Loamy      Wheat      39.0        0.0          0.0            Urea
# 97     Sandy    Millets      15.0        0.0         41.0             DAP
# 98     Black  Sugarcane      12.0        0.0         10.0           20-20
# 99       NaN        NaN       NaN        NaN          NaN             NaN
#
# [100 rows x 9 columns]

# %%
from sklearn import preprocessing
lb = preprocessing.LabelEncoder()
crop_data['Soil Type'] = lb.fit_transform(crop_data['Soil Type'])
crop_data['Crop Type'] = lb.fit_transform(crop_data['Crop Type'])
print(crop_data)
# Out:
#                                           Temparature  Humidity   Moisture  \
# 0                                                  26       52.0      38.0
# 1                                                  29       52.0      45.0
# 2                                                  34       65.0      62.0
# 3                                                  32       62.0      34.0
# 4                                                  28       54.0      46.0
# ..                                                ...        ...       ...
# 95                                                 30       60.0      27.0
# 96                                                 38       72.0      51.0
# 97                                                 36       60.0      43.0
# 98                                                 29       58.0      57.0
# 99  C:\Users\lahar\Downloads\cropprice (1)\croppri...        NaN       NaN
#
#     Soil Type  Crop Type  Nitrogen  Potassium  Phosphorous Fertilizer Name
# 0           4          3      37.0        0.0          0.0            Urea
# 1           2          8      12.0        0.0         36.0             DAP
# 2           0          1       7.0        9.0         30.0        14-35-14
# 3           3          9      22.0        0.0         20.0           28-28
# 4           1          6      35.0        0.0          0.0            Urea
# ..        ...        ...       ...        ...          ...             ...
# 95          3          9       4.0       17.0         17.0        10-26-26
# 96          2         10      39.0        0.0          0.0            Urea
# 97          4          4      15.0        0.0         41.0             DAP
# 98          0          8      12.0        0.0         10.0           20-20
# 99          5         11       NaN        NaN          NaN             NaN
#
# [100 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Assuming crop_data contains your dataset

# Splitting the data into features (x) and target variable (y)
x = crop_data.drop(["Fertilizer Name"], axis=1)
print(x)
y = crop_data["Fertilizer Name"]

# Splitting the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=5)

# Initializing the Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Training the classifier on the training data
rf_classifier.fit(x_train, y_train)

# Making predictions on the testing data
y_pred = rf_classifier.predict(x_test)

# Calculating the accuracy of the classifier
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
#                                           Temparature  Humidity   Moisture  \
# 0                                                  26       52.0      38.0
# 1                                                  29       52.0      45.0
# 2                                                  34       65.0      62.0
# 3                                                  32       62.0      34.0
# 4                                                  28       54.0      46.0
# ..                                                ...        ...       ...
# 95                                                 30       60.0      27.0
# 96                                                 38       72.0      51.0
# 97                                                 36       60.0      43.0
# 98                                                 29       58.0      57.0
# 99  C:\Users\lahar\Downloads\cropprice (1)\croppri...        NaN       NaN
#
#     Soil Type  Crop Type  Nitrogen  Potassium  Phosphorous
# 0           4          3      37.0        0.0          0.0
# 1           2          8      12.0        0.0         36.0
# 2           0          1       7.0        9.0         30.0
# 3           3          9      22.0        0.0         20.0
# 4           1          6      35.0        0.0          0.0
# ..        ...        ...       ...        ...          ...
# 95          3          9       4.0       17.0         17.0
# 96          2         10      39.0        0.0          0.0
# 97          4          4      15.0        0.0         41.0
# 98          0          8      12.0        0.0         10.0
# 99          5         11       NaN        NaN          NaN
#
# [100 rows x 8 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18812\697093461.py in ?()
#      15 # Initializing the Random Forest classifier
#      16 rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
#      17
#      18 # Training the classifier on the training data
# ---> 19 rf_classifier.fit(x_train, y_train)
#      20
#      21 # Making predictions on the testing data
#      22 y_pred = rf_classifier.predict(x_test)
#
# c:\Python311\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1347                 skip_parameter_validation=(
#    1348                     prefer_skip_nested_validation or global_skip_validation
#    1349                 )
#    1350             ):
# -> 1351                 return fit_method(estimator, *args, **kwargs)
#
# c:\Python311\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     359         # Validate or convert input data
#     360         if issparse(y):
#     361             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     362
# --> 363         X, y = self._validate_data(
#     364             X,
#     365             y,
#     366             multi_output=True,
#
# c:\Python311\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     646                 if "estimator" not in check_y_params:
#     647                     check_y_params = {**default_check_params, **check_y_params}
#     648                 y = check_array(y, input_name="y", **check_y_params)
#     649             else:
# --> 650                 X, y = check_X_y(X, y, **check_params)
#     651             out = X, y
#     652
#     653         if not no_val_X and check_params.get("ensure_2d", True):
#
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1188         raise ValueError(
#    1189             f"{estimator_name} requires y to be passed, but the target y is None"
#    1190         )
#    1191
# -> 1192     X = check_array(
#    1193         X,
#    1194         accept_sparse=accept_sparse,
#    1195         accept_large_sparse=accept_large_sparse,
#
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     948                         )
#     949                     array = xp.astype(array, dtype, copy=False)
#     950                 else:
#     951                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 952             except ComplexWarning as complex_warning:
#     953                 raise ValueError(
#     954                     "Complex data not supported\n{}\n".format(array)
#     955                 ) from complex_warning
#
# c:\Python311\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     517         # Use NumPy API to support order
#     518         if copy is True:
#     519             array = numpy.array(array, order=order, dtype=dtype)
#     520         else:
# --> 521             array = numpy.asarray(array, order=order, dtype=dtype)
#     522
#     523         # At this point array is a NumPy ndarray. We convert it to an array
#     524         # container that is consistent with the input's namespace.
#
# c:\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, dtype)
#    2148     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2149         values = self._values
# -> 2150         arr = np.asarray(values, dtype=dtype)
#    2151         if (
#    2152             astype_is_view(values.dtype, arr.dtype)
#    2153             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'C:\\Users\\lahar\\Downloads\\cropprice (1)\\cropprice\\cropprice\\static'

# %%
import joblib
joblib.dump(rf_classifier,'Fertilizer.pkl')
# Out:
# ['Fertilizer.pkl']
